# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Exploratory Data Analysis Mini Project </h1>

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >1. DESCRIPTIVE STATISTICS</h4>
#
# >#### 1. Create a dataframe using below data and answer the below questions:
#
#         Hourly_Income = [1000,2009,24418,444478,324235,243242,3434234,7567457,9235,238237,1312,3412]
#         Hourly_Expense =  [651361,217371,2746,2356,13436,5732,346346,3463,1132,23534,242235,235235]
#         family_members_count = [3,4,2,3,1,4,5,6,3,6,3,5]
#         House_rent = [1299,2300,3411,3422,4566,4211,4600,736,672,0,734,2374]
#         Highest_income_Member = ["Olivia","George","Isla","Harry","Ava","Noah","Sophia","Jacobi","Freddie","Ella","Grace","Ella"]
#
#
# >##### A. Display the five point summary of the data.
# >##### B. What is the mean of the hourly expense?
# >##### C. What is the median of the hourly expense?
# >##### D. Find the family member with maximum income and using a suitable graph.
# >##### E. Calculate IQR(the difference between 75% and 25% quartile) for `Hourly_Income` and `Hourly_Expense`.
# >##### F. Calculate the standard deviation for first 2 columns.
# >##### G. Calculate variance for the first 4 columns

# %%
# importing libraries

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# creating a dataframe

df1=pd.DataFrame({'Hourly_Income':[1000,2009,24418,444478,324235,243242,3434234,7567457,9235,238237,1312,3412],
    'Hourly_Expense':[651361,217371,2746,2356,13436,5732,346346,3463,1132,23534,242235,235235],
    'family_members_count':[3,4,2,3,1,4,5,6,3,6,3,5],
    'House_rent':[1299,2300,3411,3422,4566,4211,4600,736,672,0,734,2374],
    'Highest_income_Member':["Olivia","George","Isla","Harry","Ava","Noah","Sophia","Jacobi","Freddie","Ella","Grace","Ella"]})

df1
# Out:
#     Hourly_Income  Hourly_Expense  family_members_count  House_rent  \
# 0            1000          651361                     3        1299
# 1            2009          217371                     4        2300
# 2           24418            2746                     2        3411
# 3          444478            2356                     3        3422
# 4          324235           13436                     1        4566
# 5          243242            5732                     4        4211
# 6         3434234          346346                     5        4600
# 7         7567457            3463                     6         736
# 8            9235            1132                     3         672
# 9          238237           23534                     6           0
# 10           1312          242235                     3         734
# 11           3412          235235                     5        2374
#
#    Highest_income_Member
# 0                 Olivia
# 1                 George
# ...

# %%
# A. Display the five point summary of the data.

df1.describe()
# Out:
#        Hourly_Income  Hourly_Expense  family_members_count   House_rent
# count   1.200000e+01       12.000000             12.000000    12.000000
# mean    1.024439e+06   145412.250000              3.750000  2360.416667
# std     2.274083e+06   202831.565333              1.544786  1661.663813
# min     1.000000e+03     1132.000000              1.000000     0.000000
# 25%     3.061250e+03     3283.750000              3.000000   735.500000
# 50%     1.313275e+05    18485.000000              3.500000  2337.000000
# 75%     3.542958e+05   236985.000000              5.000000  3619.250000
# max     7.567457e+06   651361.000000              6.000000  4600.000000

# %%
# B. What is the mean of the hourly expense?

print('Mean of Hourly_Expense column in dataframe is :',df1['Hourly_Expense'].mean())
# Out:
# Mean of Hourly_Expense column in dataframe is : 145412.25

# %%
# C. What is the median of the hourly expense?

print('Median of Hourly_Expense column in dataframe is :',df1['Hourly_Expense'].median())
# Out:
# Median of Hourly_Expense column in dataframe is : 18485.0

# %%
# D. Find the family member with maximum income and using a suitable graph.

plt.figure(figsize=[15,8])

sns.barplot(x=df1['Highest_income_Member'],y=df1['Hourly_Income'])

plt.xlabel('Highest_income_Member',size=14)

plt.ylabel('Hourly_Income',size=13)

plt.show()

# %% [markdown]
# family member with maximum income is 'Jacobi'

# %%
# E. Calculate IQR(the difference between 75% and 25% quartile) for Hourly_Income and Hourly_Expense.

IQR_HI=(df1['Hourly_Income'].quantile(0.75))-(df1['Hourly_Income'].quantile(0.25))

IQR_HE=(df1['Hourly_Expense'].quantile(0.75))-(df1['Hourly_Expense'].quantile(0.25))

print('IQR of Hourly_Expense column in dataframe is :',IQR_HE)

print('\nIQR of Hourly_Income column in dataframe is :',IQR_HI)
# Out:
# IQR of Hourly_Expense column in dataframe is : 233701.25
#
# IQR of Hourly_Income column in dataframe is : 351234.5

# %%
# F. Calculate the standard deviation for first 2 columns.

df1.iloc[:,0:2].std()
# Out:
# Hourly_Income     2.274083e+06
# Hourly_Expense    2.028316e+05
# dtype: float64

# %%
# G. Calculate variance for the first 4 columns

df1.var()
# Out:
# Hourly_Income           5.171452e+12
# Hourly_Expense          4.114064e+10
# family_members_count    2.386364e+00
# House_rent              2.761127e+06
# dtype: float64

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >2. Preliminary Wrangling,</h4>
#
# >### Dataset Information:
#
# Dataset recording people to invest in each other in a way that is financially and socially rewarding. On loans, borrowers list loan requests between $ 2,000 and $ 35,000 and individual investors invest as little as $ 25 in each loan listing they select. Prosper handles the servicing of the loan on behalf of the matched borrowers and investors.
#
#
#
#
# >#### A. Read the dataset called Pri-Load.csv
# >#### B.  Check the data type and adjust datatype for all other categorical columns.
# >#### C. If you find any of the missing values in the ProsperRating column, then drop it.

# %%
#A

df2=pd.read_csv('Pri-Load.csv')

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ListingCreationDate        1035 non-null   object
#  1   Term                       1035 non-null   int64
#  2   LoanStatus                 1035 non-null   object
#  3   ClosedDate                 479 non-null    object
#  4   BorrowerAPR                1035 non-null   float64
#  5   BorrowerRate               1035 non-null   float64
#  6   LenderYield                1035 non-null   float64
#  7   ProsperRating (Alpha)      783 non-null    object
#  8   ProsperScore               783 non-null    float64
#  9   ListingCategory (numeric)  1035 non-null   int64
#  10  BorrowerState              983 non-null    object
#  11  Occupation                 996 non-null    object
#  12  EmploymentStatus           1010 non-null   object
# ...

# %%
#B

for i in df2.columns:
    print(i,len(df2[i].unique()),sep=' '*(26-len(i)))
    
print('')
    
print('length of datafrmae df2 is ',len(df2))
# Out:
# ListingCreationDate       1033
# Term                      3
# LoanStatus                9
# ClosedDate                441
# BorrowerAPR               561
# BorrowerRate              387
# LenderYield               397
# ProsperRating (Alpha)     8
# ProsperScore              12
# ListingCategory (numeric) 19
# BorrowerState             49
# Occupation                62
# EmploymentStatus          9
# AmountDelinquent          128
# StatedMonthlyIncome       350
# LoanCurrentDaysDelinquent 146
# LoanOriginalAmount        119
# LoanOriginationDate       665
# LoanOriginationQuarter    31
# MonthlyLoanPayment        869
# LP_InterestandFees        969
# Investors                 266
#
# length of datafrmae df2 is  1035

# %% [markdown]
# 1) Judging by unique values in different columns, as shown above, let us assume, a 'Category Column' is one, which has less than    20 unique values out of 1035 rows present in dataframe.
#
# 2) So, by this logic, we need to convert datatype of 'Term','LoanStatus','ProsperRating (Alpha)','ProsperScore',
#    'ListingCategory (numeric)','EmploymentStatus' columns to 'Category' Datatype.

# %%
#B

df2[['Term','LoanStatus','ProsperRating (Alpha)','ProsperScore', 'ListingCategory (numeric)','EmploymentStatus']]=df2[['Term','LoanStatus','ProsperRating (Alpha)','ProsperScore', 'ListingCategory (numeric)','EmploymentStatus']].astype('category')

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ListingCreationDate        1035 non-null   object
#  1   Term                       1035 non-null   category
#  2   LoanStatus                 1035 non-null   category
#  3   ClosedDate                 479 non-null    object
#  4   BorrowerAPR                1035 non-null   float64
#  5   BorrowerRate               1035 non-null   float64
#  6   LenderYield                1035 non-null   float64
#  7   ProsperRating (Alpha)      783 non-null    category
#  8   ProsperScore               783 non-null    category
#  9   ListingCategory (numeric)  1035 non-null   category
#  10  BorrowerState              983 non-null    object
#  11  Occupation                 996 non-null    object
#  12  EmploymentStatus           1010 non-null   category
# ...

# %% [markdown]
# As we can see from above, columns such as 'Term','LoanStatus','ProsperRating (Alpha)','ProsperScore', 'ListingCategory (numeric)','EmploymentStatus' have been changed to 'Category' datatype.

# %%
#C

for i in df2['ProsperRating (Alpha)']:
    if i is np.nan:
        df2.drop(columns=['ProsperRating (Alpha)'],inplace=True)
        break
        
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ListingCreationDate        1035 non-null   object
#  1   Term                       1035 non-null   category
#  2   LoanStatus                 1035 non-null   category
#  3   ClosedDate                 479 non-null    object
#  4   BorrowerAPR                1035 non-null   float64
#  5   BorrowerRate               1035 non-null   float64
#  6   LenderYield                1035 non-null   float64
#  7   ProsperScore               783 non-null    category
#  8   ListingCategory (numeric)  1035 non-null   category
#  9   BorrowerState              983 non-null    object
#  10  Occupation                 996 non-null    object
#  11  EmploymentStatus           1010 non-null   category
#  12  AmountDelinquent           954 non-null    float64
# ...

# %% [markdown]
# As you can see above, 'ProsperRating (Alpha)' column has been droped from dataset,since it has null value.

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >3. UNIVARIATE ANALYSIS</h4>
#
# >#### A. What are the main features of interest in your dataset?
#
#     Step1: Apply Univariate analysis using suitable charts for[ Loan status, Employment Status, Stated Monthly Income]
#
#     Step2: Check if any column distribution skew or not.
#
#     Step3: Write at least 2 observations for each visualization.

# %%
# univariate analysis for 'Loan Status' column

plt.figure(figsize=[15,10])

sns.countplot(x='LoanStatus',data=df2)

plt.title('Count Plot of Loan Status',size=20)

plt.xlabel('Loan Status',size=14)

plt.ylabel('Count',size=14)

plt.tight_layout()

# %% [markdown]
# 1) As we can see from above count plot, there are more Loans which are in 'current' status.
#
# 2) The number of Loans which are 'cancelled' is very negligible.

# %%
# univariate analysis for 'Employment Status' column

plt.figure(figsize=[15,10])

sns.countplot(x='EmploymentStatus',data=df2)

plt.title('Count Plot of Employment Status',size=20)

plt.xlabel('Employment Status',size=14)

plt.ylabel('Count',size=14)

plt.tight_layout()

# %% [markdown]
# 1) As we can see from above count plot, more number of individuals in dataset are employed. which implies more number of 'employed' people apply for loan.
#
# 2) Less number of 'Not employed' and 'Retired' individuals apply for loan.

# %%
# univariate analysis for 'Stated Monthly Income' column

plt.figure(figsize=[15,8])

sns.violinplot(x='StatedMonthlyIncome',data=df2)

plt.xlabel('StatedMonthlyIncome',size=14)

plt.ylabel('Density',size=14)

plt.show()

# %% [markdown]
# 1) 'StatedMonthlyIncome' column from dataset is right skewed, which indicates outliers present above upper whisker.
#
# 2) Most of the data in 'StatedMonthlyIncome' column lies between 0 and 15000.

# %%
# Check if any column distribution skew or not? .

df2.hist(figsize=[15,8])

plt.tight_layout()

# %%
# Check if any column distribution skew or not? .

df2.skew()
# Out:
# BorrowerAPR                   0.267334
# BorrowerRate                  0.314124
# LenderYield                   0.331794
# AmountDelinquent             15.554333
# StatedMonthlyIncome           3.225084
# LoanCurrentDaysDelinquent     3.694044
# LoanOriginalAmount            1.180358
# MonthlyLoanPayment            1.247707
# LP_InterestandFees            2.345340
# Investors                     2.303866
# dtype: float64

# %% [markdown]
# 'AmountDelinquent' column has more skewness followed by 'LoanCurrentDaysDelinquent' and 'StatedMonthlyIncome' columns.

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >4. BIVARIATE ANALYSIS</h4>
#
# >#### A. Check the correlation matrix for all numeric variables. Maintain the Strong positive and Negative correlations columns.
# >#### B. Check the relation between `LoanOriginalAmount` and `BorrowerAPR` columns.
#
#     Step1: Use subplots.
#
#         Plot1: Scatter Plot of LoanOriginalAmount and BorrowerAPR columns
#
#         Plot2: HeatMap of LoanOriginalAmount and BorrowerAPR
#
#     Step2: Write your observations.
#
# >#### C.Display the seperate box plot for `y = BorrowerAPR`  with x1 = `LoanStatus`, x2 = `EmploymentStatus` columns.Write your observations.

# %%
#4A

df2=pd.read_csv('Pri-Load.csv')

correlation=df2.corr()

Strong_Corr=correlation[abs(correlation)>0.7]

Strong_Corr.dropna(thresh=2,axis=1).dropna(how='all')
# Out:
#                     BorrowerAPR  BorrowerRate  LenderYield  \
# BorrowerAPR            1.000000      0.989962     0.989498
# BorrowerRate           0.989962      1.000000     0.998986
# LenderYield            0.989498      0.998986     1.000000
# LoanOriginalAmount          NaN           NaN          NaN
# MonthlyLoanPayment          NaN           NaN          NaN
#
#                     LoanOriginalAmount  MonthlyLoanPayment
# BorrowerAPR                        NaN                 NaN
# BorrowerRate                       NaN                 NaN
# LenderYield                        NaN                 NaN
# LoanOriginalAmount            1.000000            0.938081
# MonthlyLoanPayment            0.938081            1.000000

# %%
#4B

fig, axes = plt.subplots(1, 2, figsize=(20, 10), sharey=True)

sns.scatterplot(y='LoanOriginalAmount',x='BorrowerAPR',data=df2,ax=axes[0])

sns.histplot(data=df2, x="BorrowerAPR", y="LoanOriginalAmount",bins=50,cbar=True,ax=axes[1])

fig.tight_layout()

# %% [markdown]
# 1) As you can see from above scatter and heatmap plot between 'LoanOriginalAmount' and 'BorrowerAPR',there is a weak
#    coorelation between them.
#
# 2) From heatmap above, you can see that more number of data points are concentrated at higher 'BorrowerAPR' and lower
#    'LoanOriginalAmount', judging by blackspot on heatmap.

# %%
#4C

fig, axes = plt.subplots(1, 2, figsize=(20, 10), sharey=True)

s=sns.boxplot(ax=axes[0], x='LoanStatus', y='BorrowerAPR',data=df2)

axes[0].tick_params(axis='x', rotation=90)

sns.boxplot(ax=axes[1], x='EmploymentStatus', y='BorrowerAPR',data=df2)

axes[1].tick_params(axis='x', rotation=90)

axes[1].set_ylabel('') 

fig.tight_layout()

# %% [markdown]
# 1) As you can see from above spread of 'BorrowerAPR' data is more amongst 'Self-employed' individuals and also who are having
#    Loan status has 'Completed'.
#
# 2) There is single data point of 'BorrowerAPR' in case of Loan Status 'Cancelled' and 'Past Due(31-60 days)'

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >5.  MULTI VARIATE ANALYSIS, FEATURE ENGINEERING</h4>
#
# >#### A. Write a program
#
#     Step 1: Create a  condition = 'LoanStatus'== 'Completed'| 'LoanStatus' == 'Defaulted' |\'LoanStatus' == 'Chargedoff'
#
#     Step2: Create a user define function  using condition and `LoanStatus` column.
#
#     Hint: df['LoanStatus'] = df.apply(user define function , axis=1)
#
#         Sample output :
#
#
#         Completed    168
#
#         Defaulted     59
#
#
# >#### B. Write a program
#
#     Step 1: Create a  dictionary called categories = 1: 'Debt Consolidation', 2: 'Home Improvement', 3: 'Business', 6: 'Auto', 7: 'Other'
#
#     Step2: Create a user define function  using categories and `ListingCategory (numeric)` column.
#
#     Hint: df['ListingCategory (numeric)'] = df.apply(user define function , axis=1)
#
#         Sample output :
#
#
#         Debt Consolidation    106
#
#         Other                  65
#
#         Business               25
#
#         Home Improvement       22
#
#         Auto                    9
#
# >#### C. Display the box plot for `ProsperRating (Alpha)` vs `LoanOriginalAmount` and hue = `Loan Status`[Completed,Defaulted]. Write your observations.
#
# >#### D. Display the catplot for `ProsperRating (Alpha)` vs `ListingCategory (numeric)`[Debt Consolidation,Other,Business,Home Improvement,Auto] and hue = `Loan Status`[Completed,Defaulted]. Write your observations.

# %%
#5A

df2=pd.read_csv('Pri-Load.csv')

def LS(x):
    if np.nan not in list(x):
        if list(x)[2]=='Chargedoff':
            return 'Defaulted'
        else:
            return list(x)[2]
            
    
df2['LoanStatus']=df2.apply(LS,axis=1)

z=df2['LoanStatus'].value_counts()

for i in range(len(z)):
    print(z.index[i],z[i],sep='  ',end='\n\n')
# Out:
# Completed  168
#
# Defaulted  59

# %%
#5B

def Listing_category(x):
    categories = {1: 'Debt Consolidation', 2: 'Home Improvement', 3: 'Business', 6: 'Auto', 7: 'Other'}
    if np.nan not in list(x):
        if list(x)[9] not in categories.keys():
            return categories[7]
        else:
            return categories[x[9]]
        
df2['ListingCategory (numeric)']=df2.apply(Listing_category,axis=1)

z=df2['ListingCategory (numeric)'].value_counts()

for i in range(len(z)):
    print(z.index[i],z[i],sep=' '*((len(z.index[0])-len(z.index[i]))+1),end='\n\n')
# Out:
# Debt Consolidation 106
#
# Other              65
#
# Business           25
#
# Home Improvement   22
#
# Auto               9

# %%
# 5c

plt.figure(figsize=[15,8])

sns.boxplot(x='ProsperRating (Alpha)',y='LoanOriginalAmount',hue='LoanStatus',data=df2)

plt.xlabel('Prosper Rating (Alpha)',size=14)

plt.ylabel('LoanOriginalAmount',size=14)

plt.show()

# %%
df3=df2[['LoanOriginalAmount','ProsperRating (Alpha)','LoanStatus']]

df4=df3[df3['ProsperRating (Alpha)']=='HR']

df4[df4['LoanStatus']=='Defaulted']
# Out:
#      LoanOriginalAmount ProsperRating (Alpha) LoanStatus
# 15                 4000                    HR  Defaulted
# 100                4000                    HR  Defaulted
# 107                4000                    HR  Defaulted
# 112                4000                    HR  Defaulted
# 157                4000                    HR  Defaulted
# 186                4000                    HR  Defaulted
# 200                4000                    HR  Defaulted
# 266                4000                    HR  Defaulted
# 328                4000                    HR  Defaulted
# 379                4000                    HR  Defaulted
# 419                4000                    HR  Defaulted
# 493                4000                    HR  Defaulted
# 501                1000                    HR  Defaulted
# 543                3000                    HR  Defaulted
# 789                3151                    HR  Defaulted
# ...

# %% [markdown]
# 1) As you can see from above boxplot , the spread of 'LoanOriginalAmount' for 'Completed' data is greater or equal to   'Defaulted' for all Prosper Rating categories.
#
# 2) There is a single datapoint of 'LoanOriginalAmount' present for 'ProsperRating' of 'A' and 'B'.

# %%
#5D

plt.figure(figsize=[15,8])

g=sns.catplot(x='ProsperRating (Alpha)',y='ListingCategory (numeric)',hue='LoanStatus',data=df2,height=10, aspect=1.5,kind='swarm')

plt.xlabel('Prosper Rating (Alpha)',size=14)

plt.ylabel('Listing Category',size=14)

plt.show()

# %% [markdown]
# 1) As you can see from above swarmplot, more number of data points are present for 'Debt Consolidation' Listing Cattegory.
#
# 2) Across prosper ratings, as 'Defaulted' loan status data points increases , prosper rating decreases(i.e prosper rating of 'B'  has more 'defaulted' data points compared to 'A', and 'C' will have more than 'B' and so on ) for all 'Listing Categories'.
